# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import optuna

from optuna.samplers import TPESampler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression,ElasticNet
from sklearn.cross_decomposition import PLSRegression
from sklearn.kernel_ridge import KernelRidge

from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
# load the dataset
training_df = pd.read_excel('drought_training_df_without_outliers.xlsx')

training_df.head()
# Out:
#       339     341     342     344     345     346     348     349     351  \
# 0  0.1481  0.1818  0.1748  0.1486  0.1045  0.0782  0.0904  0.0830  0.1101
# 1  0.1422  0.1360  0.1384  0.1283  0.1103  0.0967  0.1014  0.1040  0.0934
# 2  0.0978  0.0920  0.1038  0.0981  0.0793  0.0613  0.0477  0.0520  0.0545
# 3  0.1422  0.1360  0.1538  0.1283  0.1241  0.1161  0.1074  0.0876  0.0831
# 4  0.1333  0.1280  0.1307  0.0981  0.1034  0.0838  0.0776  0.0767  0.0779
#
#       352  ...    2499    2501    2503    2505    2507    2509    2511  \
# 0  0.1168  ...  0.0332  0.0347  0.0323  0.0308  0.0360  0.0346  0.0320
# 1  0.0819  ...  0.0560  0.0589  0.0560  0.0551  0.0563  0.0554  0.0533
# 2  0.0698  ...  0.0280  0.0252  0.0269  0.0275  0.0293  0.0311  0.0284
# 3  0.0722  ...  0.0456  0.0473  0.0484  0.0452  0.0428  0.0450  0.0486
# 4  0.0722  ...  0.0373  0.0347  0.0323  0.0330  0.0360  0.0369  0.0344
#
#      2514    2516  Water Potential (Mpa)
# 0  0.0328  0.0344              -0.089632
# 1  0.0547  0.0528              -0.148237
# 2  0.0279  0.0294              -0.128243
# 3  0.0425  0.0479              -0.164785
# 4  0.0340  0.0405              -0.326122
#
# [5 rows x 995 columns]

# %%
# ---------------------------------
# Define predictors and target
# ---------------------------------
X = training_df.drop(columns = ['Water Potential (Mpa)'])
y = training_df['Water Potential (Mpa)']

# %%
# Feature scaling
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# Splitting the Dataset
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # <font color = Orange> Multiple Linear Regression - PLSR

# %%
# Define the objective function for Optuna
def objective(trial):
    # Set the range for n_components to be integers between 1 and the number of features
    n_components = trial.suggest_int('n_components', 1, X_train.shape[1])
    # Set the range for max_iter to be between 100 and 1000
    max_iter = trial.suggest_int('max_iter', 100, 1000)
    
    # Create the PLSR model with the specified hyperparameters
    model = PLSRegression(n_components=n_components, max_iter=max_iter)
    
    # Fit the model to the training data
    model.fit(X_train, y_train)
    
    # Get the MSE of the model on the testing data
    mse = metrics.mean_squared_error(y_test, model.predict(X_test))
    
    # Return mse as the objective value
    return mse

# Create the Optuna study
study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=37))

# Optimize the objective function
study.optimize(objective, n_trials=100)

# Print the number of finished trials
print("Number of finished trials: ", len(study.trials))

# Print the best trial and save as a variable
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
# Create the model using the best parameters
best_plsr = PLSRegression(n_components=trial.params['n_components'], max_iter=trial.params['max_iter'])

# Fit the model
best_plsr.fit(X_train, y_train)

# Make predictions
y_pred = best_plsr.predict(X_test)

# Model Evaluation
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/sklearn/cross_decomposition/_pls.py:302: UserWarning: Y residual is constant at iteration 39
#   warnings.warn(f"Y residual is constant at iteration {k}")
# [I 2024-02-25 20:35:10,401] Trial 99 finished with value: 3.5058166504695767 and parameters: {'n_components': 107, 'max_iter': 208}. Best is trial 65 with value: 1.2785647965903424.
# Number of finished trials:  100
# Best trial:
#   Value: 1.2785647965903424
#   Params:
#     n_components: 2
#     max_iter: 173
# Mean Squared Error: 1.2785647965903424
# Root Mean Squared Error: 1.1307363957131398
# R-Squared value: 0.5752174225904743

# %%
# Get the coefficients from the trained PLSRegression model
coefficients = best_plsr.coef_.flatten()

# Get the names of the features
feature_names = X.columns

# Create a dictionary to store feature coefficients with their corresponding names
feature_coefficients_dict = dict(zip(feature_names, coefficients))

# Sort the features by absolute coefficient values
sorted_features = sorted(feature_coefficients_dict.items(), key=lambda x: abs(x[1]), reverse=True)

# Print the top N features and their coefficients
top_n = 3  # specify the number of top features you want to display
print(f"Top {top_n} Features:")
for feature, coefficient in sorted_features[:top_n]:
    print(f"{feature}: {coefficient}")
# Out:
# Top 3 Features:
# 1898: -0.005658673273980415
# 1902: -0.005647443111727369
# 1894: -0.00561076805429346

# %% [markdown]
# # <font color = Blue> Elastic Net

# %%
# Tune the hyperparameters using Optuna
def objective(trial):
    
    # Set the range for alpha to be uniform between 0.0 and 1.0, alpha is the regularization parameter
    alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
    # Set the range for l1_ratio to be uniform between 0.0 and 1.0, l1_ratio is the ElasticNet mixing parameter
    l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
    # Set the range for max_iter to be between 100 and 1000, max_iter is the maximum number of iterations
    max_iter = trial.suggest_int('max_iter', 100, 1000)
    # Create the ElasticNet model with the specified hyperparameters
    model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, max_iter=max_iter)
    
    # Fit the model to the training data
    model.fit(X_train, y_train)
    # Get the MSE of the model on the testing data
    mse = metrics.mean_squared_error(y_test, model.predict(X_test))
    # Return mse as the objective value
    return mse

# Create the Optuna study, we maximize the objective function (the score)
# model.score() returns the coefficient of determination R^2 of the prediction 
# i.e. the percentage of the variance in the target variable that is predictable from the feature variables
study = optuna.create_study(direction='minimize', sampler = TPESampler(seed=37))
study.optimize(objective, n_trials=100)

# Print the number of finished trials
print("Number of finished trials: ", len(study.trials))

# Print the best trial and save as a variable
print("Best trial:")
trial = study.best_trial

# Print the value of the final trial and the best parameters
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
# Create the model using the best parameters
best_elastic_net = ElasticNet(alpha=study.best_params['alpha'], l1_ratio=study.best_params['l1_ratio'], max_iter=study.best_params['max_iter'])

# Fit the model
best_elastic_net.fit(X_train, y_train)

# Make predictions
y_pred = best_elastic_net.predict(X_test)

# Model Evaluation
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R-Squared value:', r2_score(y_test, y_pred))
# Out:
# [I 2024-02-25 20:35:10,477] A new study created in memory with name: no-name-5b639a7d-7bdd-4add-8e63-b856c618f8fd
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:10,495] Trial 0 finished with value: 2.548527028667546 and parameters: {'alpha': 0.9444966028573069, 'l1_ratio': 0.4640981743044076, 'max_iter': 273}. Best is trial 0 with value: 2.548527028667546.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35

# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.537e+00, tolerance: 5.990e-03
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-02-25 20:35:11,412] Trial 16 finished with value: 3.067857661651732 and parameters: {'alpha': 0.01852795795045803, 'l1_ratio': 0.02183039456886099, 'max_iter': 907}. Best is trial 9 with value: 1.6117380880014536.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,447] Trial 17 finished with value: 1.8116679320638556 and parameters: {'alpha': 0.4379027108138038, 'l1_ratio': 0.4009405704824356, 'max_iter': 570}. Best is trial 9 with value: 1.6117380880014536.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,500] Trial 18 finished with value: 1.6057600154041436 and parameters: {'alpha': 0.27071380291647296, 'l1_ratio': 0.20977163678941094, 'max_iter': 762}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,559] Trial 19 finished with value: 1.6239783749350658 and parameters: {'alpha': 0.22354284842045136, 'l1_ratio': 0.18941736800690356, 'max_iter': 754}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.622e+00, tolerance: 5.990e-03
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-02-25 20:35:11,644] Trial 20 finished with value: 2.1624502859205235 and parameters: {'alpha': 0.4131857702397715, 'l1_ratio': 0.0004094924478996731, 'max_iter': 524}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,698] Trial 21 finished with value: 1.6254410299019226 and parameters: {'alpha': 0.24655133569294224, 'l1_ratio': 0.2826248000855088, 'max_iter': 896}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,763] Trial 22 finished with value: 1.6157936707005964 and parameters: {'alpha': 0.4762675195604788, 'l1_ratio': 0.18567324349083605, 'max_iter': 841}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,826] Trial 23 finished with value: 1.642267740424292 and parameters: {'alpha': 0.66153861746002, 'l1_ratio': 0.1560088749081958, 'max_iter': 850}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,865] Trial 24 finished with value: 1.9412115704150255 and parameters: {'alpha': 0.5075026717583074, 'l1_ratio': 0.44422684888517633, 'max_iter': 696}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:11,922] Trial 25 finished with value: 1.644091279944715 and parameters: {'alpha': 0.46922373110717425, 'l1_ratio': 0.22358683759023912, 'max_iter': 833}. Best is trial 18 with value: 1.6057600154041436.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:12,000] Trial 26 finished with value: 1.5883451435806955 and parameters: {'alpha': 0.854288020922526, 'l1_ratio': 0.09465717340187929, 'max_iter': 640}. Best is trial 26 with value: 1.5883451435806955.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:12,071] Trial 27 finished with value: 1.5676300043966878 and parameters: {'alpha': 0.9409353630535533, 'l1_ratio': 0.07699330444992586, 'max_iter': 523}. Best is trial 27 with value: 1.5676300043966878.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:12,153] Trial 28 finished with value: 1.5526085889861037 and parameters: {'alpha': 0.931531622174598, 'l1_ratio': 0.06690057812467162, 'max_iter': 498}. Best is trial 28 with value: 1.5526085889861037.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.691e-02, tolerance: 5.990e-03
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-02-25 20:35:12,237] Trial 29 finished with value: 1.5499037447874415 and parameters: {'alpha': 0.980205532630313, 'l1_ratio': 0.03048647103559987, 'max_iter': 491}. Best is trial 29 with value: 1.5499037447874415.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35

# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:15,460] Trial 91 finished with value: 1.5348287670620626 and parameters: {'alpha': 0.9553921117175909, 'l1_ratio': 0.04494268005847039, 'max_iter': 569}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.816e+00, tolerance: 5.990e-03
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-02-25 20:35:15,543] Trial 92 finished with value: 1.9171819735229618 and parameters: {'alpha': 0.9491643730104055, 'l1_ratio': 0.002472527320359151, 'max_iter': 543}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:15,617] Trial 93 finished with value: 1.5587725819394216 and parameters: {'alpha': 0.8367131623773028, 'l1_ratio': 0.07942121096606033, 'max_iter': 569}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.581e-02, tolerance: 5.990e-03
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-02-25 20:35:15,688] Trial 94 finished with value: 1.544696060448581 and parameters: {'alpha': 0.8942380563730616, 'l1_ratio': 0.039515261956858526, 'max_iter': 403}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:15,815] Trial 95 finished with value: 1.6508571533881116 and parameters: {'alpha': 0.9600309412050568, 'l1_ratio': 0.1093785990317854, 'max_iter': 482}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.153e-02, tolerance: 5.990e-03
#   model = cd_fast.enet_coordinate_descent(
# [I 2024-02-25 20:35:15,905] Trial 96 finished with value: 1.6133578807038413 and parameters: {'alpha': 0.9271329729307121, 'l1_ratio': 0.021475500029621487, 'max_iter': 612}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:16,018] Trial 97 finished with value: 1.5384744485204855 and parameters: {'alpha': 0.9748507294451445, 'l1_ratio': 0.056443237068894175, 'max_iter': 575}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:16,113] Trial 98 finished with value: 1.5745632155317535 and parameters: {'alpha': 0.9085680321368547, 'l1_ratio': 0.08284401025328036, 'max_iter': 956}. Best is trial 64 with value: 1.5331650076886405.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:5: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3317287144.py:7: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   l1_ratio = trial.suggest_uniform('l1_ratio', 0.0, 1.0)
# [I 2024-02-25 20:35:16,171] Trial 99 finished with value: 1.7001824290472827 and parameters: {'alpha': 0.8768538689252894, 'l1_ratio': 0.14569008197518463, 'max_iter': 531}. Best is trial 64 with value: 1.5331650076886405.
# Number of finished trials:  100
# Best trial:
#   Value: 1.5331650076886405
#   Params:
#     alpha: 0.997461584259315
#     l1_ratio: 0.04051118438392984
#     max_iter: 727
# Mean Squared Error: 1.5331650076886405
# Root Mean Squared Error: 1.2382104052577818
# R-Squared value: 0.4906305997968571

# %%
# Get the coefficients from the trained ElasticNet model
coefficients = best_elastic_net.coef_

# Get the names of the features
feature_names = X.columns

# Create a dictionary to store feature coefficients with their corresponding names
feature_coefficients_dict = dict(zip(feature_names, coefficients))

# Sort the features by absolute coefficient values
sorted_features = sorted(feature_coefficients_dict.items(), key=lambda x: abs(x[1]), reverse=True)

# Print the top N features and their coefficients
top_n = 3  # specify the number of top features you want to display
print(f"Top {top_n} Features:")
for feature, coefficient in sorted_features[:top_n]:
    print(f"{feature}: {coefficient}")
# Out:
# Top 3 Features:
# 354: 0.07159012199887901
# 357: -0.06404561795037672
# 386: -0.06156613593130939

# %% [markdown]
# # <font color = Red> Non-linear Kernel Ridge Regression (KRR)

# %%
# Define the objective function for Optuna
def objective(trial):
    # Set the range for alpha to be uniform between 0.0 and 1.0
    alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
    # Set the range for gamma to be loguniform between 1e-6 and 1e6
    gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
    # Set the range for kernel to be categorical between 'linear' and 'rbf'
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf'])
    
    # Create the Kernel Ridge Regression model with the specified hyperparameters
    model = KernelRidge(alpha=alpha, gamma=gamma, kernel=kernel)
    
    # Fit the model to the training data
    model.fit(X_train, y_train)
    
    # Get the MSE of the model on the testing data
    mse = metrics.mean_squared_error(y_test, model.predict(X_test))
    
    # Return mse as the objective value
    return mse

# Create the Optuna study
study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=37))

# Optimize the objective function
study.optimize(objective, n_trials=100)

# Print the number of finished trials
print("Number of finished trials: ", len(study.trials))

# Print the best trial and save as a variable
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
# Create the model using the best parameters
best_krr = KernelRidge(alpha=trial.params['alpha'], gamma=trial.params['gamma'], kernel=trial.params['kernel'])

# Fit the model
best_krr.fit(X_train, y_train)

# Make predictions
y_pred = best_krr.predict(X_test)

# Model Evaluation
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R-Squared value:', r2_score(y_test, y_pred))
# Out:
# [I 2024-02-25 20:35:16,245] A new study created in memory with name: no-name-2e4524ef-5933-4539-a6f2-b6c48974cc88
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,292] Trial 0 finished with value: 6.197462058662588 and parameters: {'alpha': 0.9444966028573069, 'gamma': 0.3708327584362581, 'kernel': 'rbf'}. Best is trial 0 with value: 6.197462058662588.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,298] Trial 1 finished with value: 6.197462058662679 and parameters: {'alpha': 0.6200842101736271, 'gamma': 162.4382154062861, 'kernel': 'rbf'}. Best is trial 0 with value: 6.197462058662588.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,303] Trial 2 finished with value: 27.926492039432045 and parameters: {'alpha': 0.28197907007423595, 'gamma': 1099.2463841530512, 'kernel': 'linear'}. Best is trial 0 with value: 6.197462058662588.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,308] Trial 3 finished with value: 24.932955314830032 and parameters: {'alpha': 0.4434888437784015, 'gamma': 364404.9174304399, 'kernel': 'linear'}. Best is trial 0 with value: 6.197462058662588.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,315] Trial 4 finished with value: 6.197462058662679 and parameters: {'alpha': 0.5959511331875896, 'gamma': 7.594922485525402, 'kernel': 'rbf'}. Best is trial 0 with value: 6.197462058662588.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,321] Trial 5 finished with value: 1.6844519237350424 and parameters: {'alpha': 0.05122982888761973, 'gamma': 4.1470938813138165e-05, 'kernel': 'rbf'}. Best is trial 5 with value: 1.6844519237350424.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,329] Trial 6 finished with value: 6.197462058662679 and parameters: {'alpha': 0.803410838278303, 'gamma': 439453.21929558367, 'kernel': 'rbf'}. Best is trial 5 with value: 1.6844519237350424.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:16,336] Trial 7 finished with value: 30.507177289635 and parameters: {'alpha': 0.17893744751587604, 'gamma': 67672.75546006153, 'kernel': 'linear'}. Best is trial 5 with value: 1.6844519237350424.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35

# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:19,193] Trial 98 finished with value: 6.197462058662679 and parameters: {'alpha': 0.02009199538561132, 'gamma': 71.31188502109116, 'kernel': 'rbf'}. Best is trial 55 with value: 1.5831636632375798.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:4: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   alpha = trial.suggest_uniform('alpha', 0.0, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/295769073.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   gamma = trial.suggest_loguniform('gamma', 1e-6, 1e6)
# [I 2024-02-25 20:35:19,212] Trial 99 finished with value: 3.446442251681849 and parameters: {'alpha': 0.5623652702412058, 'gamma': 1.22523222523329e-06, 'kernel': 'rbf'}. Best is trial 55 with value: 1.5831636632375798.
# Number of finished trials:  100
# Best trial:
#   Value: 1.5831636632375798
#   Params:
#     alpha: 0.0026347696402181965
#     gamma: 3.2849396736376654e-06
#     kernel: rbf
# Mean Squared Error: 1.5831636632375798
# Root Mean Squared Error: 1.2582383173459548
# R-Squared value: 0.4740193511313783

# %%
# Get the dual coefficients from the trained KernelRidge model
coefficients = best_krr.dual_coef_

# Calculate the squared magnitude of coefficients (as they are signed)
squared_magnitude = np.abs(coefficients) ** 2

# Get the names of the features
feature_names = X.columns

# Create a dictionary to store feature coefficients with their corresponding names
feature_coefficients_dict = dict(zip(feature_names, squared_magnitude))

# Sort the features by their squared magnitude (importance)
sorted_features = sorted(feature_coefficients_dict.items(), key=lambda x: x[1], reverse=True)

# Print the top N features and their coefficients
top_n = 3  # specify the number of top features you want to display
print(f"Top {top_n} Features:")
for feature, magnitude in sorted_features[:top_n]:
    print(f"{feature}: {magnitude}")
# Out:
# Top 3 Features:
# 364: 681113.1554454194
# 351: 650971.5438523926
# 344: 534004.7833262517

# %% [markdown]
# # Principal Component Regression (PCR)

# %%
# Create an instance of PCA
pca = PCA(random_state= 37)

# Perform PCA on the predictors DataFrame
pca.fit(X)

# Calculate the cumulative sum of the explained variance ratio
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# Plot the cumulative explained variance with a vertical line at 95%
plt.plot(cumulative_explained_variance)
plt.axhline(y=0.95, color='r', linestyle='-')

# Find the number of components that explain at least 95% of the variance
pca_n_components = np.where(cumulative_explained_variance >= 0.95)[0][0] + 1

print(f'Number of components that explain at least 95% of the variance: {pca_n_components}')
# Out:
# Number of components that explain at least 95% of the variance: 3

# %%
# Define the number of principal components to retain
n_components = pca_n_components

# Create a pipeline with PCA and Linear Regression
pipeline = make_pipeline(PCA(n_components), LinearRegression())

# Fit the model
pipeline.fit(X_train, y_train)

# Make predictions
y_pred = pipeline.predict(X_test)

# Model Evaluation
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R-Squared value:', r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 1.2923625064365363
# Root Mean Squared Error: 1.1368212288818926
# R-Squared value: 0.5706333555440132

# %%
# Get the principal components from the trained PCA model within the pipeline
principal_components = pipeline.named_steps['pca'].components_

# Calculate the squared loadings of each feature on the principal components
squared_loadings = principal_components ** 2

# Sum the squared loadings across principal components to get feature importance
feature_importance = squared_loadings.sum(axis=0)

# Get the names of the original features
feature_names = X.columns

# Create a dictionary to store feature importance with their corresponding names
feature_importance_dict = dict(zip(feature_names, feature_importance))

# Sort the features by importance
sorted_features = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print the top N features and their importance
top_n = 3  # specify the number of top features you want to display
print(f"Top {top_n} Features:")
for feature, importance in sorted_features[:top_n]:
    print(f"{feature}: {importance}")
# Out:
# Top 3 Features:
# 516: 0.007582500860643137
# 514: 0.007567127839993883
# 517: 0.007528902309532999

# %% [markdown]
# # <font color = Purple> Ensemble Methods

# %% [markdown]
# ## <font color = darkgreen> Random Forest Regression

# %%
# Define the objective function for Optuna
def objective(trial):
    # Define the search space for hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 50, 150)
    max_depth = trial.suggest_int('max_depth', 5, 30)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    
    # Create the Random Forest model with the specified hyperparameters
    model = RandomForestRegressor(
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        min_samples_split=min_samples_split, 
        min_samples_leaf=min_samples_leaf
    )
    
    # Fit the model to the training data
    model.fit(X_train, y_train)
    
    # Get the MSE of the model on the testing data
    mse = mean_squared_error(y_test, model.predict(X_test))
    
    # Return the MSE as the objective value to minimize
    return mse

# Create the Optuna study
study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=37))

# Optimize the objective function
study.optimize(objective, n_trials=100)

# Print the best trial and save as a variable
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
# Create the Random Forest model using the best parameters
best_rf_model = RandomForestRegressor(
    n_estimators=trial.params['n_estimators'], 
    max_depth=trial.params['max_depth'], 
    min_samples_split=trial.params['min_samples_split'], 
    min_samples_leaf=trial.params['min_samples_leaf']
)

# Fit the model
best_rf_model.fit(X_train, y_train)

# Make predictions
y_pred = best_rf_model.predict(X_test)

# Model Evaluation
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R-Squared value:', r2_score(y_test, y_pred))
# Out:
# [I 2024-02-25 20:35:19,608] A new study created in memory with name: no-name-496b6e8d-3bdd-4ae5-beb0-c7a136beeb14
# [I 2024-02-25 20:35:20,554] Trial 0 finished with value: 2.965199850232444 and parameters: {'n_estimators': 145, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 6}. Best is trial 0 with value: 2.965199850232444.
# [I 2024-02-25 20:35:21,094] Trial 1 finished with value: 3.1216304609331034 and parameters: {'n_estimators': 112, 'max_depth': 22, 'min_samples_split': 3, 'min_samples_leaf': 8}. Best is trial 0 with value: 2.965199850232444.
# [I 2024-02-25 20:35:21,493] Trial 2 finished with value: 3.0646373336137462 and parameters: {'n_estimators': 78, 'max_depth': 24, 'min_samples_split': 17, 'min_samples_leaf': 7}. Best is trial 0 with value: 2.965199850232444.
# [I 2024-02-25 20:35:22,309] Trial 3 finished with value: 2.7271141252224993 and parameters: {'n_estimators': 94, 'max_depth': 30, 'min_samples_split': 19, 'min_samples_leaf': 2}. Best is trial 3 with value: 2.7271141252224993.
# [I 2024-02-25 20:35:22,677] Trial 4 finished with value: 3.158012445138904 and parameters: {'n_estimators': 110, 'max_depth': 19, 'min_samples_split': 15, 'min_samples_leaf': 10}. Best is trial 3 with value: 2.7271141252224993.
# [I 2024-02-25 20:35:23,121] Trial 5 finished with value: 2.8548919255529914 and parameters: {'n_estimators': 55, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 3 with value: 2.7271141252224993.
# [I 2024-02-25 20:35:24,172] Trial 6 finished with value: 2.7538750441539404 and parameters: {'n_estimators': 131, 'max_depth': 30, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 3 with value: 2.7271141252224993.
# [I 2024-02-25 20:35:24,871] Trial 7 finished with value: 2.631632226573023 and parameters: {'n_estimators': 68, 'max_depth': 28, 'min_samples_split': 16, 'min_samples_leaf': 2}. Best is trial 7 with value: 2.631632226573023.
# [I 2024-02-25 20:35:25,200] Trial 8 finished with value: 3.1369670441080455 and parameters: {'n_estimators': 86, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 9}. Best is trial 7 with value: 2.631632226573023.
# [I 2024-02-25 20:35:25,981] Trial 9 finished with value: 2.794405657517569 and parameters: {'n_estimators': 114, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 5}. Best is trial 7 with value: 2.631632226573023.
# [I 2024-02-25 20:35:26,766] Trial 10 finished with value: 2.408975169024957 and parameters: {'n_estimators': 50, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 10 with value: 2.408975169024957.
# [I 2024-02-25 20:35:27,617] Trial 11 finished with value: 2.3479700344265075 and parameters: {'n_estimators': 52, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 11 with value: 2.3479700344265075.
# [I 2024-02-25 20:35:28,530] Trial 12 finished with value: 2.4029138399864056 and parameters: {'n_estimators': 54, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 11 with value: 2.3479700344265075.
# [I 2024-02-25 20:35:29,208] Trial 13 finished with value: 2.5253373833203905 and parameters: {'n_estimators': 66, 'max_depth': 12, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 11 with value: 2.3479700344265075.
# [I 2024-02-25 20:35:30,470] Trial 14 finished with value: 2.0659369700621215 and parameters: {'n_estimators': 63, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 14 with value: 2.0659369700621215.
# [I 2024-02-25 20:35:31,330] Trial 15 finished with value: 2.758950396563391 and parameters: {'n_estimators': 69, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 14 with value: 2.0659369700621215.
# [I 2024-02-25 20:35:32,674] Trial 16 finished with value: 2.045134659069009 and parameters: {'n_estimators': 82, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:33,437] Trial 17 finished with value: 2.6540519137400316 and parameters: {'n_estimators': 84, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 3}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:34,292] Trial 18 finished with value: 2.684619495226944 and parameters: {'n_estimators': 97, 'max_depth': 9, 'min_samples_split': 20, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:34,907] Trial 19 finished with value: 2.744978145069551 and parameters: {'n_estimators': 73, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:35,397] Trial 20 finished with value: 2.9304530454413755 and parameters: {'n_estimators': 86, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 6}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:36,332] Trial 21 finished with value: 2.2627627090236078 and parameters: {'n_estimators': 61, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:37,320] Trial 22 finished with value: 2.3197077647054356 and parameters: {'n_estimators': 64, 'max_depth': 17, 'min_samples_split': 11, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:38,075] Trial 23 finished with value: 2.656078547566895 and parameters: {'n_estimators': 62, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:39,321] Trial 24 finished with value: 2.174793250927119 and parameters: {'n_estimators': 79, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:39,863] Trial 25 finished with value: 2.864744903567274 and parameters: {'n_estimators': 77, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:40,919] Trial 26 finished with value: 2.7326749364522387 and parameters: {'n_estimators': 94, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:42,188] Trial 27 finished with value: 2.6567927660991937 and parameters: {'n_estimators': 102, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:43,425] Trial 28 finished with value: 2.1166603836878846 and parameters: {'n_estimators': 81, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:44,970] Trial 29 finished with value: 2.6668926058280182 and parameters: {'n_estimators': 147, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:45,701] Trial 30 finished with value: 2.7819896991809445 and parameters: {'n_estimators': 90, 'max_depth': 17, 'min_samples_split': 15, 'min_samples_leaf': 3}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:47,157] Trial 31 finished with value: 2.3948371813891067 and parameters: {'n_estimators': 78, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:48,886] Trial 32 finished with value: 2.22625799868382 and parameters: {'n_estimators': 104, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:49,300] Trial 33 finished with value: 3.118831871336924 and parameters: {'n_estimators': 79, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 7}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:50,356] Trial 34 finished with value: 2.5081476627813557 and parameters: {'n_estimators': 73, 'max_depth': 7, 'min_samples_split': 13, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:51,587] Trial 35 finished with value: 2.397784886419504 and parameters: {'n_estimators': 84, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:52,242] Trial 36 finished with value: 3.0549147603294373 and parameters: {'n_estimators': 58, 'max_depth': 9, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:52,837] Trial 37 finished with value: 3.0529732851165203 and parameters: {'n_estimators': 118, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 7}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:54,332] Trial 38 finished with value: 2.7934077879101586 and parameters: {'n_estimators': 72, 'max_depth': 23, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:35:59,460] Trial 39 finished with value: 2.2012353014876327 and parameters: {'n_estimators': 139, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:00,626] Trial 40 finished with value: 3.160228047553012 and parameters: {'n_estimators': 91, 'max_depth': 19, 'min_samples_split': 11, 'min_samples_leaf': 8}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:04,579] Trial 41 finished with value: 2.0712117535050045 and parameters: {'n_estimators': 139, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:06,873] Trial 42 finished with value: 2.6592065869106465 and parameters: {'n_estimators': 135, 'max_depth': 26, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:09,146] Trial 43 finished with value: 2.1968293114804567 and parameters: {'n_estimators': 120, 'max_depth': 26, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:10,925] Trial 44 finished with value: 2.554048853995979 and parameters: {'n_estimators': 124, 'max_depth': 13, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:12,492] Trial 45 finished with value: 2.165274880595453 and parameters: {'n_estimators': 107, 'max_depth': 30, 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:13,301] Trial 46 finished with value: 2.817757418373999 and parameters: {'n_estimators': 108, 'max_depth': 29, 'min_samples_split': 18, 'min_samples_leaf': 3}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:13,807] Trial 47 finished with value: 3.1360690430015294 and parameters: {'n_estimators': 142, 'max_depth': 27, 'min_samples_split': 16, 'min_samples_leaf': 10}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:15,773] Trial 48 finished with value: 2.097494897695823 and parameters: {'n_estimators': 128, 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:17,523] Trial 49 finished with value: 2.6233576626400135 and parameters: {'n_estimators': 133, 'max_depth': 24, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:18,406] Trial 50 finished with value: 2.8176005768023336 and parameters: {'n_estimators': 124, 'max_depth': 25, 'min_samples_split': 15, 'min_samples_leaf': 5}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:20,588] Trial 51 finished with value: 2.370575686998325 and parameters: {'n_estimators': 149, 'max_depth': 30, 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:22,525] Trial 52 finished with value: 2.171994847875425 and parameters: {'n_estimators': 125, 'max_depth': 28, 'min_samples_split': 14, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:24,380] Trial 53 finished with value: 2.151378633345247 and parameters: {'n_estimators': 128, 'max_depth': 29, 'min_samples_split': 17, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:25,695] Trial 54 finished with value: 2.535951113938484 and parameters: {'n_estimators': 138, 'max_depth': 29, 'min_samples_split': 18, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:26,834] Trial 55 finished with value: 2.6465995686920776 and parameters: {'n_estimators': 129, 'max_depth': 28, 'min_samples_split': 17, 'min_samples_leaf': 3}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:28,500] Trial 56 finished with value: 2.28665124960546 and parameters: {'n_estimators': 142, 'max_depth': 27, 'min_samples_split': 20, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:29,520] Trial 57 finished with value: 2.591387860528259 and parameters: {'n_estimators': 98, 'max_depth': 22, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:31,407] Trial 58 finished with value: 2.2099580224516875 and parameters: {'n_estimators': 129, 'max_depth': 29, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:32,702] Trial 59 finished with value: 2.589152573819641 and parameters: {'n_estimators': 114, 'max_depth': 19, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 16 with value: 2.045134659069009.
# [I 2024-02-25 20:36:33,432] Trial 60 finished with value: 2.0227800584120903 and parameters: {'n_estimators': 57, 'max_depth': 27, 'min_samples_split': 19, 'min_samples_leaf': 1}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:34,078] Trial 61 finished with value: 2.1170210792559274 and parameters: {'n_estimators': 56, 'max_depth': 27, 'min_samples_split': 19, 'min_samples_leaf': 1}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:35,168] Trial 62 finished with value: 2.2983084363061645 and parameters: {'n_estimators': 57, 'max_depth': 25, 'min_samples_split': 20, 'min_samples_leaf': 1}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:36,004] Trial 63 finished with value: 2.3297197663793394 and parameters: {'n_estimators': 67, 'max_depth': 27, 'min_samples_split': 19, 'min_samples_leaf': 1}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:36,641] Trial 64 finished with value: 2.592301678159769 and parameters: {'n_estimators': 61, 'max_depth': 26, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:36,841] Trial 65 finished with value: 3.0673758353419043 and parameters: {'n_estimators': 50, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 9}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:37,556] Trial 66 finished with value: 2.435173821643072 and parameters: {'n_estimators': 55, 'max_depth': 24, 'min_samples_split': 18, 'min_samples_leaf': 1}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:38,310] Trial 67 finished with value: 2.5489068136690625 and parameters: {'n_estimators': 69, 'max_depth': 18, 'min_samples_split': 12, 'min_samples_leaf': 2}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:39,012] Trial 68 finished with value: 2.3787976485609774 and parameters: {'n_estimators': 53, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 1}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:39,649] Trial 69 finished with value: 2.9289972640975095 and parameters: {'n_estimators': 59, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 3}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:40,469] Trial 70 finished with value: 2.601052189313616 and parameters: {'n_estimators': 63, 'max_depth': 28, 'min_samples_split': 13, 'min_samples_leaf': 2}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:41,852] Trial 71 finished with value: 2.1839085354684897 and parameters: {'n_estimators': 82, 'max_depth': 30, 'min_samples_split': 17, 'min_samples_leaf': 1}. Best is trial 60 with value: 2.0227800584120903.
# [I 2024-02-25 20:36:42,799] Trial 72 finished with value: 1.9770626440520955 and parameters: {'n_estimators': 71, 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:43,843] Trial 73 finished with value: 2.169112227004411 and parameters: {'n_estimators': 76, 'max_depth': 25, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:44,910] Trial 74 finished with value: 2.4997523832569453 and parameters: {'n_estimators': 71, 'max_depth': 27, 'min_samples_split': 13, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:45,618] Trial 75 finished with value: 2.8024679975358295 and parameters: {'n_estimators': 66, 'max_depth': 28, 'min_samples_split': 14, 'min_samples_leaf': 2}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:47,113] Trial 76 finished with value: 2.2390861433279046 and parameters: {'n_estimators': 75, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:48,560] Trial 77 finished with value: 2.149110385260826 and parameters: {'n_estimators': 90, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:49,626] Trial 78 finished with value: 2.4732698001835676 and parameters: {'n_estimators': 64, 'max_depth': 26, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:50,572] Trial 79 finished with value: 2.582859510330307 and parameters: {'n_estimators': 81, 'max_depth': 23, 'min_samples_split': 15, 'min_samples_leaf': 2}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:51,477] Trial 80 finished with value: 2.249951027034689 and parameters: {'n_estimators': 59, 'max_depth': 29, 'min_samples_split': 14, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:52,868] Trial 81 finished with value: 2.017959891089588 and parameters: {'n_estimators': 88, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:53,421] Trial 82 finished with value: 2.8949252027742904 and parameters: {'n_estimators': 85, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 6}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:54,831] Trial 83 finished with value: 2.0782695267142444 and parameters: {'n_estimators': 93, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:56,177] Trial 84 finished with value: 2.419101214804769 and parameters: {'n_estimators': 88, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:57,817] Trial 85 finished with value: 2.234768450459345 and parameters: {'n_estimators': 95, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:36:59,451] Trial 86 finished with value: 2.140894526354184 and parameters: {'n_estimators': 93, 'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:00,518] Trial 87 finished with value: 2.678635362589957 and parameters: {'n_estimators': 88, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:02,037] Trial 88 finished with value: 2.2434103728804375 and parameters: {'n_estimators': 81, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:03,253] Trial 89 finished with value: 2.51684644186477 and parameters: {'n_estimators': 103, 'max_depth': 7, 'min_samples_split': 11, 'min_samples_leaf': 2}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:05,200] Trial 90 finished with value: 2.2958019621428587 and parameters: {'n_estimators': 100, 'max_depth': 9, 'min_samples_split': 3, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:06,266] Trial 91 finished with value: 2.172896946194139 and parameters: {'n_estimators': 71, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:07,379] Trial 92 finished with value: 2.2067290511305533 and parameters: {'n_estimators': 87, 'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:08,235] Trial 93 finished with value: 2.2590113236313307 and parameters: {'n_estimators': 56, 'max_depth': 16, 'min_samples_split': 12, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:09,356] Trial 94 finished with value: 2.782709096539396 and parameters: {'n_estimators': 83, 'max_depth': 11, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:10,459] Trial 95 finished with value: 2.3421795623011743 and parameters: {'n_estimators': 92, 'max_depth': 27, 'min_samples_split': 20, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:11,122] Trial 96 finished with value: 2.1629938136248503 and parameters: {'n_estimators': 52, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:12,079] Trial 97 finished with value: 2.178808119024209 and parameters: {'n_estimators': 66, 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:13,022] Trial 98 finished with value: 2.682105996705891 and parameters: {'n_estimators': 96, 'max_depth': 28, 'min_samples_split': 16, 'min_samples_leaf': 2}. Best is trial 72 with value: 1.9770626440520955.
# [I 2024-02-25 20:37:14,189] Trial 99 finished with value: 2.1889093644544926 and parameters: {'n_estimators': 74, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 72 with value: 1.9770626440520955.
# Best trial:
#   Value: 1.9770626440520955
#   Params:
#     n_estimators: 71
#     max_depth: 29
#     min_samples_split: 15
#     min_samples_leaf: 1
# Mean Squared Error: 2.202849409705509
# Root Mean Squared Error: 1.4841999224179703
# R-Squared value: 0.2681387346224807

# %% [markdown]
# ## <font color = darkblue> Variable Importance Information of RF

# %%
# Extract feature importances
feature_importances = best_rf_model.feature_importances_

# Create a series with feature names and their importance
features = pd.Series(feature_importances, index = X.columns)

# Sort the features by importance
features = features.sort_values(ascending=False)

# Select the top 3 features
top_3_features = features[:3]

# Plot the top 3 feature importances
plt.figure(figsize=(10, 6))
top_3_features.plot(kind='bar')
plt.title('Top 3 Feature Importances in Random Forest Model')
plt.ylabel('Importance')
plt.xlabel('Features')

plt.show()

# %% [markdown]
# ## <font color = darkgreen> Gradient Boosting Regression

# %%
# Define the objective function for Optuna
def objective(trial):
    # Define the search space for hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 50, 150)
    max_depth = trial.suggest_int('max_depth', 3, 10)  # Adjust the range for max_depth
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
    
    # Create the Gradient Boosting model with the specified hyperparameters
    model = GradientBoostingRegressor(
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        learning_rate=learning_rate  # Pass learning_rate to the model
    )
    
    # Fit the model to the training data
    model.fit(X_train, y_train)
    
    # Get the MSE of the model on the testing data
    mse = mean_squared_error(y_test, model.predict(X_test))
    
    # Return the MSE as the objective value to minimize
    return mse

# Create the Optuna study
study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=37))

# Optimize the objective function
study.optimize(objective, n_trials=100)

# Print the best trial and save as a variable
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
# Create the Gradient Boosting model using the best parameters
best_gb_model = GradientBoostingRegressor(
    n_estimators=trial.params['n_estimators'], 
    max_depth=trial.params['max_depth'], 
    learning_rate=trial.params['learning_rate']  # Pass learning_rate to the model
)

# Fit the model
best_gb_model.fit(X_train, y_train)

# Make predictions
y_pred = best_gb_model.predict(X_test)

# Model Evaluation
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R-Squared value:', r2_score(y_test, y_pred))
# Out:
# [I 2024-02-25 20:37:15,371] A new study created in memory with name: no-name-2c27f95e-71b6-41c8-84b4-4f6fa0a2eb38
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:37:19,801] Trial 0 finished with value: 2.6458950927493152 and parameters: {'n_estimators': 145, 'max_depth': 6, 'learning_rate': 0.027351552606144185}. Best is trial 0 with value: 2.6458950927493152.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:37:23,914] Trial 1 finished with value: 2.6135441771919248 and parameters: {'n_estimators': 108, 'max_depth': 7, 'learning_rate': 0.07158016157168567}. Best is trial 1 with value: 2.6135441771919248.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:37:27,184] Trial 2 finished with value: 2.6070671341701668 and parameters: {'n_estimators': 60, 'max_depth': 8, 'learning_rate': 0.03537811630668124}. Best is trial 2 with value: 2.6070671341701668.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20
. Best is trial 62 with value: 1.551082466873722.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:40:29,662] Trial 93 finished with value: 1.7711962725597987 and parameters: {'n_estimators': 70, 'max_depth': 3, 'learning_rate': 0.054196511060915165}. Best is trial 62 with value: 1.551082466873722.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:40:31,944] Trial 94 finished with value: 1.7104149361099565 and parameters: {'n_estimators': 67, 'max_depth': 3, 'learning_rate': 0.0501035530923549}. Best is trial 62 with value: 1.551082466873722.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:40:33,745] Trial 95 finished with value: 1.6682301256586063 and parameters: {'n_estimators': 61, 'max_depth': 3, 'learning_rate': 0.04420799450432404}. Best is trial 62 with value: 1.551082466873722.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:40:35,740] Trial 96 finished with value: 1.5590175692179842 and parameters: {'n_estimators': 64, 'max_depth': 3, 'learning_rate': 0.038423003254241056}. Best is trial 62 with value: 1.551082466873722.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:40:38,069] Trial 97 finished with value: 1.8203065383324637 and parameters: {'n_estimators': 102, 'max_depth': 4, 'learning_rate': 0.028637811943791964}. Best is trial 62 with value: 1.551082466873722.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:40:39,324] Trial 98 finished with value: 1.8507818664707378 and parameters: {'n_estimators': 73, 'max_depth': 3, 'learning_rate': 0.032509995670640175}. Best is trial 62 with value: 1.551082466873722.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/517228355.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)  # Add learning_rate hyperparameter
# [I 2024-02-25 20:40:41,792] Trial 99 finished with value: 1.835160381420482 and parameters: {'n_estimators': 141, 'max_depth': 3, 'learning_rate': 0.03822760965230235}. Best is trial 62 with value: 1.551082466873722.
# Best trial:
#   Value: 1.551082466873722
#   Params:
#     n_estimators: 63
#     max_depth: 3
#     learning_rate: 0.03683418485271125
# Mean Squared Error: 1.633105476104069
# Root Mean Squared Error: 1.2779301530616096
# R-Squared value: 0.4574269875323602

# %%
# Get feature importances from the trained GradientBoostingRegressor model
feature_importances = best_gb_model.feature_importances_

# Get the names of the features
feature_names = X.columns

# Create a dictionary to store feature importance scores with their corresponding names
feature_importance_dict = dict(zip(feature_names, feature_importances))

# Sort the features by importance
sorted_features = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print the top N features and their importance scores
top_n = 3  # specify the number of top features you want to display
print(f"Top {top_n} Features:")
for feature, importance in sorted_features[:top_n]:
    print(f"{feature}: {importance}")
# Out:
# Top 3 Features:
# 374: 0.13450330279077324
# 354: 0.10208403348601269
# 373: 0.07335444083763303

# %% [markdown]
# ## <font color = green> XGBoost

# %%
# Define the objective function for Optuna
def objective(trial):
    # Define the search space for hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 50, 150)
    max_depth = trial.suggest_int('max_depth', 3, 10)
    learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
    min_child_weight = trial.suggest_int('min_child_weight', 1, 10)
    subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
    colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
    
    # Create the XGBoost model with the specified hyperparameters
    model = XGBRegressor(
        n_estimators=n_estimators, 
        max_depth=max_depth, 
        learning_rate=learning_rate,
        min_child_weight=min_child_weight,
        subsample=subsample,
        colsample_bytree=colsample_bytree
    )
    
    # Fit the model to the training data
    model.fit(X_train, y_train)
    
    # Get the MSE of the model on the testing data
    mse = mean_squared_error(y_test, model.predict(X_test))
    
    # Return the MSE as the objective value to minimize
    return mse

# Create the Optuna study
study = optuna.create_study(direction='minimize', sampler=TPESampler(seed=37))

# Optimize the objective function
study.optimize(objective, n_trials=100)

# Print the best trial and save as a variable
print("Best trial:")
trial = study.best_trial
print("  Value: {}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
    
# Create the XGBoost model using the best parameters
best_xgb_model = XGBRegressor(
    n_estimators=trial.params['n_estimators'], 
    max_depth=trial.params['max_depth'], 
    learning_rate=trial.params['learning_rate'],
    min_child_weight=trial.params['min_child_weight'],
    subsample=trial.params['subsample'],
    colsample_bytree=trial.params['colsample_bytree']
)

# Fit the model
best_xgb_model.fit(X_train, y_train)

# Make predictions
y_pred = best_xgb_model.predict(X_test)

# Model Evaluation
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R-Squared value:', r2_score(y_test, y_pred))
# Out:
# [I 2024-02-25 20:40:42,932] A new study created in memory with name: no-name-cda04e27-2815-4e8b-8d78-97c3f4a77df2
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:43,571] Trial 0 finished with value: 2.5558105090733534 and parameters: {'n_estimators': 145, 'max_depth': 6, 'learning_rate': 0.027351552606144185, 'min_child_weight': 6, 'subsample': 0.8100421050868136, 'colsample_bytree': 0.842112008731587}. Best is trial 0 with value: 2.5558105090733534.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:43,744] Trial 1 finished with value: 2.957259851615774 and parameters: {'n_estimators': 60, 'max_depth': 8, 'learning_rate': 0.03537811630668124, 'min_child_weight': 8, 'subsample': 0.896352814785358, 'colsample_bytree': 0.8137002981396799}. Best is trial 0 with value: 2.5558105090733534.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:44,778] Trial 2 finished with value: 2.3784831108464144 and parameters: {'n_estimators': 94, 'max_depth': 10, 'learning_rate': 0.0907359898347597, 'min_child_weight': 2, 'subsample': 0.7979755665937949, 'colsample_bytree': 0.7866884727405066}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:45,555] Trial 3 finished with value: 2.6078114221428654 and parameters: {'n_estimators': 121, 'max_depth': 10, 'learning_rate': 0.014610684599885777, 'min_child_weight': 2, 'subsample': 0.558514253058227, 'colsample_bytree': 0.6823623803502956}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:45,969] Trial 4 finished with value: 2.5142501604176877 and parameters: {'n_estimators': 131, 'max_depth': 10, 'learning_rate': 0.03996813330365787, 'min_child_weight': 5, 'subsample': 0.589468723757938, 'colsample_bytree': 0.9512672441747777}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:46,401] Trial 5 finished with value: 2.761428524204459 and parameters: {'n_estimators': 127, 'max_depth': 4, 'learning_rate': 0.042911755108468036, 'min_child_weight': 6, 'subsample': 0.5200471337936301, 'colsample_bytree': 0.9123139915826536}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:46,669] Trial 6 finished with value: 2.8188515565008174 and parameters: {'n_estimators': 114, 'max_depth': 3, 'learning_rate': 0.08254345345232203, 'min_child_weight': 5, 'subsample': 0.5018019421849012, 'colsample_bytree': 0.7326167078381765}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:46,812] Trial 7 finished with value: 2.8357156991115877 and parameters: {'n_estimators': 84, 'max_depth': 7, 'learning_rate': 0.09431124379429702, 'min_child_weight': 9, 'subsample': 0.8760371801543867, 'colsample_bytree': 0.7324980890585063}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:47,454] Trial 8 finished with value: 2.562287840713269 and parameters: {'n_estimators': 121, 'max_depth': 3, 'learning_rate': 0.07117311490868987, 'min_child_weight': 5, 'subsample': 0.9514292302907547, 'colsample_bytree': 0.9725808161673396}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:47,906] Trial 9 finished with value: 2.7342782667600116 and parameters: {'n_estimators': 148, 'max_depth': 7, 'learning_rate': 0.09778202121844198, 'min_child_weight': 6, 'subsample': 0.6656756674360085, 'colsample_bytree': 0.7376308953876871}. Best is trial 2 with value: 2.3784831108464144.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:49,576] Trial 10 finished with value: 1.632048627073611 and parameters: {'n_estimators': 89, 'max_depth': 9, 'learning_rate': 0.0616370260304635, 'min_child_weight': 1, 'subsample': 0.7326997468789238, 'colsample_bytree': 0.5306580157938485}. Best is trial 10 with value: 1.632048627073611.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:50,631] Trial 11 finished with value: 1.5938626424558995 and parameters: {'n_estimators': 86, 'max_depth': 9, 'learning_rate': 0.06323235215201523, 'min_child_weight': 1, 'subsample': 0.7405803373219974, 'colsample_bytree': 0.5078182982864856}. Best is trial 11 with value: 1.5938626424558995.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:51,678] Trial 12 finished with value: 1.654174811586006 and parameters: {'n_estimators': 77, 'max_depth': 8, 'learning_rate': 0.06046451764405074, 'min_child_weight': 1, 'subsample': 0.6867876535967221, 'colsample_bytree': 0.5037124573331885}. Best is trial 11 with value: 1.5938626424558995.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:52,039] Trial 13 finished with value: 2.6310761469142676 and parameters: {'n_estimators': 65, 'max_depth': 9, 'learning_rate': 0.060884485773778085, 'min_child_weight': 3, 'subsample': 0.7046868309048814, 'colsample_bytree': 0.5052047587377122}. Best is trial 11 with value: 1.5938626424558995.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:52,849] Trial 14 finished with value: 1.5346792523897959 and parameters: {'n_estimators': 102, 'max_depth': 5, 'learning_rate': 0.06991559346063488, 'min_child_weight': 1, 'subsample': 0.7612392031984874, 'colsample_bytree': 0.6011586467882767}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:53,555] Trial 15 finished with value: 2.401412156264552 and parameters: {'n_estimators': 105, 'max_depth': 5, 'learning_rate': 0.07512067945773682, 'min_child_weight': 3, 'subsample': 0.6297702457674519, 'colsample_bytree': 0.6055450329134641}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:54,255] Trial 16 finished with value: 2.4102347964047968 and parameters: {'n_estimators': 104, 'max_depth': 5, 'learning_rate': 0.052399002156480814, 'min_child_weight': 3, 'subsample': 0.7705597700656516, 'colsample_bytree': 0.6138800434068319}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:54,835] Trial 17 finished with value: 1.566267793925987 and parameters: {'n_estimators': 68, 'max_depth': 5, 'learning_rate': 0.07473471573936673, 'min_child_weight': 1, 'subsample': 0.8482496114046779, 'colsample_bytree': 0.5829508208716041}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:55,213] Trial 18 finished with value: 2.491387229765609 and parameters: {'n_estimators': 53, 'max_depth': 5, 'learning_rate': 0.07900073784719441, 'min_child_weight': 4, 'subsample': 0.8527778449445889, 'colsample_bytree': 0.6273204031099782}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:55,391] Trial 19 finished with value: 3.197906753709951 and parameters: {'n_estimators': 70, 'max_depth': 4, 'learning_rate': 0.04985775733444834, 'min_child_weight': 10, 'subsample': 0.9964338447377152, 'colsample_bytree': 0.6649752963546371}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:55,888] Trial 20 finished with value: 2.0629694008353905 and parameters: {'n_estimators': 74, 'max_depth': 6, 'learning_rate': 0.07276172570898166, 'min_child_weight': 2, 'subsample': 0.8347944945119173, 'colsample_bytree': 0.569151717347433}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:56,408] Trial 21 finished with value: 1.6520828954503322 and parameters: {'n_estimators': 95, 'max_depth': 4, 'learning_rate': 0.0683146593077681, 'min_child_weight': 1, 'subsample': 0.7508592365334609, 'colsample_bytree': 0.5626611654703045}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:57,069] Trial 22 finished with value: 1.815819974608068 and parameters: {'n_estimators': 80, 'max_depth': 6, 'learning_rate': 0.08592380834378555, 'min_child_weight': 1, 'subsample': 0.9055324860601351, 'colsample_bytree': 0.5627568460251086}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:57,622] Trial 23 finished with value: 2.3506920716039326 and parameters: {'n_estimators': 51, 'max_depth': 5, 'learning_rate': 0.06553315673359855, 'min_child_weight': 2, 'subsample': 0.778738897234636, 'colsample_bytree': 0.6653105848349752}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:58,442] Trial 24 finished with value: 2.71606937450506 and parameters: {'n_estimators': 87, 'max_depth': 7, 'learning_rate': 0.08193411554989437, 'min_child_weight': 4, 'subsample': 0.7197436084612996, 'colsample_bytree': 0.5791443856418562}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:40:59,624] Trial 25 finished with value: 1.6515573909943184 and parameters: {'n_estimators': 108, 'max_depth': 8, 'learning_rate': 0.05422510097770813, 'min_child_weight': 1, 'subsample': 0.6327117742485749, 'colsample_bytree': 0.5272282943881469}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:01,359] Trial 26 finished with value: 2.4306216012328195 and parameters: {'n_estimators': 96, 'max_depth': 4, 'learning_rate': 0.07671390500017501, 'min_child_weight': 3, 'subsample': 0.8048042262503907, 'colsample_bytree': 0.6958378440863895}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:01,819] Trial 27 finished with value: 2.3891197728058984 and parameters: {'n_estimators': 63, 'max_depth': 6, 'learning_rate': 0.04612539550217083, 'min_child_weight': 2, 'subsample': 0.9308936182796256, 'colsample_bytree': 0.6368165375158724}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:02,061] Trial 28 finished with value: 2.843667527125742 and parameters: {'n_estimators': 82, 'max_depth': 9, 'learning_rate': 0.08639311474113189, 'min_child_weight': 7, 'subsample': 0.83843828312699, 'colsample_bytree': 0.5458587151132317}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:02,533] Trial 29 finished with value: 2.2635606044014343 and parameters: {'n_estimators': 135, 'max_depth': 5, 'learning_rate': 0.02252426197572935, 'min_child_weight': 4, 'subsample': 0.7520715194536577, 'colsample_bytree': 0.5965537416139736}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:03,132] Trial 30 finished with value: 1.5547535923268612 and parameters: {'n_estimators': 69, 'max_depth': 6, 'learning_rate': 0.06611753724147607, 'min_child_weight': 1, 'subsample': 0.8169546703204478, 'colsample_bytree': 0.632119105068924}. Best is trial 14 with value: 1.5346792523897959.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:03,803] Trial 31 finished with value: 1.4714889257165695 and parameters: {'n_estimators': 72, 'max_depth': 6, 'learning_rate': 0.06472951041717895, 'min_child_weight': 1, 'subsample': 0.8271421296363388, 'colsample_bytree': 0.6498523476737104}. Best is trial 31 with value: 1.4714889257165695.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:04,217] Trial 32 finished with value: 2.38243150475057 and parameters: {'n_estimators': 56, 'max_depth': 6, 'learning_rate': 0.05740910557458356, 'min_child_weight': 2, 'subsample': 0.867388653195132, 'colsample_bytree': 0.6399317609398671}. Best is trial 31 with value: 1.4714889257165695.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:05,064] Trial 33 finished with value: 1.5229609791605903 and parameters: {'n_estimators': 71, 'max_depth': 6, 'learning_rate': 0.0682735181220063, 'min_child_weight': 1, 'subsample': 0.8235104405778402, 'colsample_bytree': 0.8631761347619056}. Best is trial 31 with value: 1.4714889257165695.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:06,032] Trial 34 finished with value: 2.165429394423823 and parameters: {'n_estimators': 73, 'max_depth': 6, 'learning_rate': 0.06874057207077854, 'min_child_weight': 2, 'subsample': 0.8101087568041588, 'colsample_bytree': 0.7877149877920469}. Best is trial 31 with value: 1.4714889257165695.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:41:06,763] Trial 35 finished with value: 2.357405038075578 and parameters: {'n_estimators': 60, 'max_depth': 7, 'learning_rate': 0.03365193626382187, 'min_child_weight': 2, 'subsample': 0.8174244407635831, 'colsample_bytree': 0.8683640399248267}. Best is trial 31 with value: 1.4714889257165695.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# ...
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:17,784] Trial 88 finished with value: 2.729791545590832 and parameters: {'n_estimators': 125, 'max_depth': 10, 'learning_rate': 0.09010200849954929, 'min_child_weight': 4, 'subsample': 0.617242992003944, 'colsample_bytree': 0.9242149740183931}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:20,988] Trial 89 finished with value: 2.2565411907921753 and parameters: {'n_estimators': 139, 'max_depth': 9, 'learning_rate': 0.08834470267457581, 'min_child_weight': 1, 'subsample': 0.5414883298884664, 'colsample_bytree': 0.909450556469175}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:25,869] Trial 90 finished with value: 1.2721464099617223 and parameters: {'n_estimators': 135, 'max_depth': 10, 'learning_rate': 0.09349683331906841, 'min_child_weight': 1, 'subsample': 0.6927861605195107, 'colsample_bytree': 0.9866783885896555}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:29,966] Trial 91 finished with value: 1.3137892738059056 and parameters: {'n_estimators': 133, 'max_depth': 10, 'learning_rate': 0.09722471153232629, 'min_child_weight': 1, 'subsample': 0.6919565006755203, 'colsample_bytree': 0.9866977277935312}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:34,085] Trial 92 finished with value: 1.4164441759265718 and parameters: {'n_estimators': 133, 'max_depth': 10, 'learning_rate': 0.09745407510379787, 'min_child_weight': 1, 'subsample': 0.6567442498698868, 'colsample_bytree': 0.9868573540810874}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:37,718] Trial 93 finished with value: 1.4285171844256987 and parameters: {'n_estimators': 141, 'max_depth': 10, 'learning_rate': 0.09993030607087015, 'min_child_weight': 1, 'subsample': 0.6861778402332869, 'colsample_bytree': 0.9488681693863529}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:40,954] Trial 94 finished with value: 1.468223464446696 and parameters: {'n_estimators': 136, 'max_depth': 9, 'learning_rate': 0.09414714429984433, 'min_child_weight': 1, 'subsample': 0.7493017476563112, 'colsample_bytree': 0.9692259054371531}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:42,928] Trial 95 finished with value: 2.568827983733259 and parameters: {'n_estimators': 147, 'max_depth': 10, 'learning_rate': 0.08727912393808483, 'min_child_weight': 2, 'subsample': 0.6455713378251232, 'colsample_bytree': 0.9864982160028456}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:45,568] Trial 96 finished with value: 1.3998602076810296 and parameters: {'n_estimators': 132, 'max_depth': 9, 'learning_rate': 0.0908274455209184, 'min_child_weight': 1, 'subsample': 0.6667044149852765, 'colsample_bytree': 0.9411502281322535}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:47,901] Trial 97 finished with value: 2.5195114574125603 and parameters: {'n_estimators': 126, 'max_depth': 10, 'learning_rate': 0.08477119917130942, 'min_child_weight': 2, 'subsample': 0.7241135256361322, 'colsample_bytree': 0.9615341601163845}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:51,141] Trial 98 finished with value: 1.3556595104568538 and parameters: {'n_estimators': 122, 'max_depth': 10, 'learning_rate': 0.09575973862928491, 'min_child_weight': 1, 'subsample': 0.7732323193967536, 'colsample_bytree': 0.9741055429810216}. Best is trial 61 with value: 1.27007032530217.
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   learning_rate = trial.suggest_uniform('learning_rate', 0.01, 0.1)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   subsample = trial.suggest_uniform('subsample', 0.5, 1.0)
# /var/folders/3h/631y9grn15xf3n6ybqs6vrp40000gn/T/ipykernel_44417/3853135105.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   colsample_bytree = trial.suggest_uniform('colsample_bytree', 0.5, 1.0)
# [I 2024-02-25 20:42:54,717] Trial 99 finished with value: 1.3473758541499496 and parameters: {'n_estimators': 129, 'max_depth': 10, 'learning_rate': 0.09446528571895751, 'min_child_weight': 1, 'subsample': 0.7708887567488316, 'colsample_bytree': 0.9986201269777406}. Best is trial 61 with value: 1.27007032530217.
# Best trial:
#   Value: 1.27007032530217
#   Params:
#     n_estimators: 66
#     max_depth: 5
#     learning_rate: 0.07407494654505506
#     min_child_weight: 1
#     subsample: 0.8191204145603431
#     colsample_bytree: 0.9945464094411819
# Mean Squared Error: 1.27007032530217
# Root Mean Squared Error: 1.1269739683338609
# R-Squared value: 0.5780395739723547

# %%
# Get feature importances from the trained XGBoost model
feature_importances = best_xgb_model.feature_importances_

# Get the names of the features
feature_names = X.columns

# Create a dictionary to store feature importance scores with their corresponding names
feature_importance_dict = dict(zip(feature_names, feature_importances))

# Sort the features by importance
sorted_features = sorted(feature_importance_dict.items(), key=lambda x: x[1], reverse=True)

# Print the top N features and their importance scores
top_n = 3  # specify the number of top features you want to display
print(f"Top {top_n} Features:")
for feature, importance in sorted_features[:top_n]:
    print(f"{feature}: {importance}")
# Out:
# Top 3 Features:
# 1399: 0.16103887557983398
# 1328: 0.12644782662391663
# 568: 0.09046512097120285
