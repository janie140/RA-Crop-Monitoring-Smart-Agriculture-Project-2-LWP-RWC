# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# load the dataset
drought_df = pd.read_excel('drought_training_df_without_outliers.xlsx')

drought_df
# Out:
#        339     341     342     344     345     346     348     349     351  \
# 0   0.1481  0.1818  0.1748  0.1486  0.1045  0.0782  0.0904  0.0830  0.1101
# 1   0.1422  0.1360  0.1384  0.1283  0.1103  0.0967  0.1014  0.1040  0.0934
# 2   0.0978  0.0920  0.1038  0.0981  0.0793  0.0613  0.0477  0.0520  0.0545
# 3   0.1422  0.1360  0.1538  0.1283  0.1241  0.1161  0.1074  0.0876  0.0831
# 4   0.1333  0.1280  0.1307  0.0981  0.1034  0.0838  0.0776  0.0767  0.0779
# 5   0.0889  0.1040  0.1000  0.1056  0.0896  0.0839  0.0836  0.0877  0.0831
# 6   0.0978  0.0800  0.0769  0.0604  0.0552  0.0967  0.0776  0.0712  0.0779
# 7   0.1052  0.0733  0.1128  0.1072  0.0985  0.1134  0.1044  0.0855  0.0549
# 8   0.1626  0.1466  0.1476  0.1072  0.1062  0.1064  0.0718  0.1099  0.0989
# 9   0.1486  0.1351  0.1282  0.1176  0.1505  0.1414  0.1603  0.1304  0.1056
# 10  0.1516  0.1070  0.1015  0.1009  0.1135  0.0800  0.0809  0.0574  0.0536
# ...

# %%
drought_df.hist("Water Potential (Mpa)") #heavily left-skewed
# Out:
# array([[<Axes: title={'center': 'Water Potential (Mpa)'}>]], dtype=object)

# %%
# import tensorflow as tf
# from tensorflow.keras.losses import MeanSquaredError

# class SmoothedMeanSquaredError(MeanSquaredError):
#     def __init__(self, smoothing_factor=0.1, **kwargs):
#         super().__init__(**kwargs)
#         self.smoothing_factor = smoothing_factor

#     def call(self, y_true, y_pred):
#         target_mean = tf.reduce_mean(y_true)
#         y_true_smoothed = y_true * (1 - self.smoothing_factor) + target_mean * self.smoothing_factor
#         return super().call(y_true_smoothed, y_pred)

# # Example usage:
# smoothing_factor = 0.1
# model.compile(optimizer='adam', loss=SmoothedMeanSquaredError(smoothing_factor=smoothing_factor))

# %%
# drought_df['Log_Water_Potential'] = np.log1p(drought_df['Water Potential (Mpa)'])
# drought_df.hist("Log_Water_Potential")

# #bad result
# Out:
# /Users/trangtran/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in log1p
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# array([[<Axes: title={'center': 'Log_Water_Potential'}>]], dtype=object)

# %% [markdown]
# ## Binning

# %%
bins = np.linspace(min(drought_df['Water Potential (Mpa)']), max(drought_df['Water Potential (Mpa)']), 10)
drought_df['Binned_Water_Potential'] = np.digitize(drought_df['Water Potential (Mpa)'], bins)
drought_df.hist("Binned_Water_Potential")
# Out:
# array([[<Axes: title={'center': 'Binned_Water_Potential'}>]], dtype=object)

# %%
# save new training file
# drought_df_target_Yeo_Johnson_transform.to_excel('drought_training_Yeo_Johnson_transform.xlsx', index = False)
