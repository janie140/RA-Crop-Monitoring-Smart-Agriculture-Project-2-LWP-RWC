# 32  0.0710  ...  0.0566  0.0567  0.0554  0.0556  0.0559  0.0552  0.0541
# 33  0.0691  ...  0.0287  0.0304  0.0329  0.0326  0.0334  0.0297  0.0291
# 34  0.0543  ...  0.0636  0.0618  0.0626  0.0641  0.0602  0.0605  0.0605
# 35  0.0624  ...  0.0238  0.0243  0.0257  0.0252  0.0236  0.0219  0.0200
# 36  0.0899  ...  0.1158  0.1183  0.1176  0.1182  0.1181  0.1176  0.1167
#
#       2511    2514    2516
# 0   0.0344  0.0340  0.0405
# 1   0.0332  0.0340  0.0356
# 2   0.0486  0.0425  0.0479
# 3   0.0220  0.0201  0.0292
# 4   0.0317  0.0314  0.0342
# 5   0.0400  0.0373  0.0350
# 6   0.0712  0.0752  0.0798
# 7   0.0422  0.0432  0.0449
# 8   0.0521  0.0522  0.0513
# 9   0.0291  0.0311  0.0413
# 10  0.0499  0.0513  0.0516
# 11  0.0550  0.0588  0.0646
# 12  0.0292  0.0275  0.0302
# 13  0.0287  0.0294  0.0286
# 14  0.0287  0.0270  0.0298
# 15  0.0349  0.0308  0.0338
# 16  0.0300  0.0259  0.0238
# 17  0.0445  0.0456  0.0438
# 18  0.0495  0.0471  0.0489
# 19  0.0205  0.0211  0.0263
# 20  0.0597  0.0585  0.0646
# 21  0.0329  0.0311  0.0317
# 22  0.0328  0.0274  0.0214
# 23  0.0644  0.0634  0.0666
# 24  0.0537  0.0538  0.0460
# 25  0.0415  0.0388  0.0370
# 26  0.0366  0.0313  0.0358
# 27  0.0476  0.0475  0.0358
# 28  0.0476  0.0475  0.0485
# 29  0.1183  0.1188  0.1174
# 30  0.0331  0.0315  0.0381
# 31  0.0945  0.0969  0.0995
# 32  0.0529  0.0541  0.0633
# 33  0.0299  0.0306  0.0371
# 34  0.0621  0.0636  0.0630
# 35  0.0193  0.0209  0.0348
# 36  0.1155  0.1144  0.1193
#
# [37 rows x 994 columns]

# %%
# Round Certain Wavelengths to the Nearest Whole Number to create Indices

wavelengths = indices_df.columns[0:].astype(int)
def find_nearest(value):
  return str(wavelengths[np.abs(wavelengths-value).argmin()])

# %% [markdown]
# # Create Existing Vegetation Indices (Non Optimized)

# %%
# Mutate a new column, Disease Water Stress Index (DWSI) (x802 -x547)/(x1657+x682)
indices_df["DWSI"] = (indices_df[find_nearest(802)] -indices_df[find_nearest(547)])/(indices_df[find_nearest(1657)] + indices_df[find_nearest(682)])

# Mutate a new column, Moisture Stress Index (MSI) x1599/x819
indices_df["MSI"] = indices_df[find_nearest(1599)]/indices_df[find_nearest(819)]

# Mutate a new column, Leaf Water Vegetation Index 1 (LWVI1) (x1094 -x983)/(x1094+x983)
indices_df["LWVI1"] = (indices_df[find_nearest(1094)] -indices_df[find_nearest(983)])/(indices_df[find_nearest(1094)] + indices_df[find_nearest(983)])

# Mutate a new column, Leaf Water Vegetation Index 2 (LWVI2) (x1094 -x1205)/(x1094+x1205)
indices_df["LWVI2"] = (indices_df[find_nearest(1094)] -indices_df[find_nearest(1205)])/(indices_df[find_nearest(1094)] + indices_df[find_nearest(1205)])

# Mutate a new column, Normalized Difference Infrared Index (NDII) (x819 -x1649)/(x819+x1649)
indices_df["NDII"] = (indices_df[find_nearest(819)] -indices_df[find_nearest(1649)])/(indices_df[find_nearest(819)] + indices_df[find_nearest(1649)])

# Mutate a new column, Normalized Difference Water Index (NDWI) (x857 -x1241)/(x857+x1241)
indices_df["NDWI"] = (indices_df[find_nearest(857)] -indices_df[find_nearest(1241)])/(indices_df[find_nearest(857)] + indices_df[find_nearest(1241)])

# Mutate a new column, Water Band Index (WBI) x970/x900
indices_df["WBI"] = indices_df[find_nearest(970)]/indices_df[find_nearest(900)]

# Mutate a new column, Normalized Multi-band Drought Index (NMDI)(x860 -(x1640 -x2130))/(x860+(x1640 -x2130))
indices_df["NMDI"] = (indices_df[find_nearest(860)] - (indices_df[find_nearest(1640)] -indices_df[find_nearest(2130)])) / (indices_df[find_nearest(860)] + (indices_df[find_nearest(1640)] -indices_df[find_nearest(2130)]))

indices_df
# Out:
#        339     341     342     344     345     346     348     349     351  \
# 0   0.1333  0.1280  0.1307  0.0981  0.1034  0.0838  0.0776  0.0767  0.0779
# 1   0.0889  0.1040  0.1000  0.1056  0.0896  0.0839  0.0836  0.0877  0.0831
# 2   0.1422  0.1360  0.1538  0.1283  0.1241  0.1161  0.1074  0.0876  0.0831
# 3   0.1052  0.0733  0.1128  0.1072  0.0985  0.1134  0.1044  0.0855  0.0549
# 4   0.1626  0.1466  0.1476  0.1072  0.1062  0.1064  0.0718  0.1099  0.0989
# 5   0.1486  0.1351  0.1282  0.1176  0.1505  0.1414  0.1603  0.1304  0.1056
# 6   0.1240  0.1360  0.1515  0.1683  0.1731  0.1291  0.1010  0.0939  0.0932
# 7   0.1182  0.0816  0.1307  0.1259  0.0857  0.0787  0.0606  0.0732  0.0717
# 8   0.1159  0.1200  0.0987  0.1279  0.0888  0.0824  0.1153  0.1043  0.0901
# 9   0.0870  0.1067  0.0741  0.0814  0.0778  0.0618  0.0481  0.0435  0.0164
# 10  0.2055  0.1644  0.1375  0.1219  0.1011  0.1030  0.0857  0.0956  0.0901
# 11  0.1818  0.1515  0.1330  0.1190  0.1653  0.1581  0.1272  0.1094  0.0693
# 12  0.1085  0.0904  0.0907  0.0885  0.0889  0.0748  0.0565  0.0459  0.0432
# 13  0.0857  0.0833  0.0951  0.1214  0.1159  0.1043  0.0660  0.0555  0.0559
# 14  0.1029  0.1083  0.0805  0.0786  0.0750  0.0717  0.0720  0.0833  0.0661
# 15  0.0721  0.0943  0.1010  0.0800  0.0866  0.0782  0.0734  0.0683  0.0323
# 16  0.1443  0.1077  0.1010  0.0686  0.0541  0.0977  0.0826  0.0512  0.0889
# 17  0.1333  0.1244  0.1000  0.0830  0.0714  0.0839  0.0666  0.0732  0.0480
# 18  0.1219  0.0970  0.1054  0.0868  0.0975  0.0928  0.1090  0.0959  0.0763
# 19  0.1125  0.1059  0.1135  0.1026  0.0974  0.0785  0.0954  0.0959  0.0817
# 20  0.1351  0.1250  0.1309  0.1511  0.1477  0.1145  0.1057  0.0956  0.1023
# 21  0.1351  0.1125  0.1071  0.1163  0.1136  0.1146  0.1154  0.0956  0.0866
# 22  0.1217  0.1167  0.1098  0.1091  0.0896  0.0762  0.0597  0.0767  0.0675
# 35  0.260459  0.057824  0.962176  0.478738
# 36  0.121856  0.021073  1.005219  0.514483
#
# [37 rows x 1002 columns]

# %%
target = drought_df['RWC']
target
# Out:
# 0     98.373025
# 1     99.923489
# 2     96.795629
# 3     94.518349
# 4     95.493562
# 5     97.219048
# 6     98.601399
# 7     89.502762
# 8     84.405941
# 9     95.163890
# 10    97.818182
# 11    76.568047
# 12    89.293598
# 13    67.782427
# 14    91.197183
# 15    67.767857
# 16    78.333333
# 17    83.970856
# 18    74.397590
# 19    73.737374
# 20    76.817043
# 21    91.379310
# 22    70.295983
# 23    60.661999
# 24    85.609756
# 25    49.596774
# 26    84.946237
# 27    90.312500
# 28    82.217573
# 29    23.601974
# 30    78.639456
# 31    44.333996
# 32    53.488372
# 33    21.983732
# 34    59.808612
# 35    95.859873
# 36    42.670944
# Name: RWC, dtype: float64

# %%
bands_df = drought_df.copy()
# Drop the target column
bands_df = bands_df.drop(columns = ['RWC'])
bands_df
# Out:
#        339     341     342     344     345     346     348     349     351  \
# 0   0.1333  0.1280  0.1307  0.0981  0.1034  0.0838  0.0776  0.0767  0.0779
# 1   0.0889  0.1040  0.1000  0.1056  0.0896  0.0839  0.0836  0.0877  0.0831
# 2   0.1422  0.1360  0.1538  0.1283  0.1241  0.1161  0.1074  0.0876  0.0831
# 3   0.1052  0.0733  0.1128  0.1072  0.0985  0.1134  0.1044  0.0855  0.0549
# 4   0.1626  0.1466  0.1476  0.1072  0.1062  0.1064  0.0718  0.1099  0.0989
# 5   0.1486  0.1351  0.1282  0.1176  0.1505  0.1414  0.1603  0.1304  0.1056
# 6   0.1240  0.1360  0.1515  0.1683  0.1731  0.1291  0.1010  0.0939  0.0932
# 7   0.1182  0.0816  0.1307  0.1259  0.0857  0.0787  0.0606  0.0732  0.0717
# 8   0.1159  0.1200  0.0987  0.1279  0.0888  0.0824  0.1153  0.1043  0.0901
# 9   0.0870  0.1067  0.0741  0.0814  0.0778  0.0618  0.0481  0.0435  0.0164
# 10  0.2055  0.1644  0.1375  0.1219  0.1011  0.1030  0.0857  0.0956  0.0901
# 11  0.1818  0.1515  0.1330  0.1190  0.1653  0.1581  0.1272  0.1094  0.0693
# 12  0.1085  0.0904  0.0907  0.0885  0.0889  0.0748  0.0565  0.0459  0.0432
# 13  0.0857  0.0833  0.0951  0.1214  0.1159  0.1043  0.0660  0.0555  0.0559
# 14  0.1029  0.1083  0.0805  0.0786  0.0750  0.0717  0.0720  0.0833  0.0661
# 15  0.0721  0.0943  0.1010  0.0800  0.0866  0.0782  0.0734  0.0683  0.0323
# 16  0.1443  0.1077  0.1010  0.0686  0.0541  0.0977  0.0826  0.0512  0.0889
# 17  0.1333  0.1244  0.1000  0.0830  0.0714  0.0839  0.0666  0.0732  0.0480
# 18  0.1219  0.0970  0.1054  0.0868  0.0975  0.0928  0.1090  0.0959  0.0763
# 19  0.1125  0.1059  0.1135  0.1026  0.0974  0.0785  0.0954  0.0959  0.0817
# 20  0.1351  0.1250  0.1309  0.1511  0.1477  0.1145  0.1057  0.0956  0.1023
# 32  0.0529  0.0541  0.0633
# 33  0.0299  0.0306  0.0371
# 34  0.0621  0.0636  0.0630
# 35  0.0193  0.0209  0.0348
# 36  0.1155  0.1144  0.1193
#
# [37 rows x 994 columns]

# %% [markdown]
# # **Optimized** Vegetation Indices for this dataset

# %%
###### Determine the columns for SD Index

# Create the find_optimal_indices function
def find_optimal_indices(data, target):
    num_columns = data.shape[1]
    best_correlation = 0
    best_indices = None

    for i in range(num_columns - 1):
        for j in range(i + 1, num_columns):
            subtracted_data = data.iloc[:, i] - data.iloc[:, j]
            correlation = np.corrcoef(subtracted_data, target)[0, 1]
            if abs(correlation) > best_correlation:
                best_correlation = abs(correlation)
                best_indices = (i, j)

    return best_indices

# Find the best indices
best_indices_SD = find_optimal_indices(bands_df, target)

# Convert best_indices tuple to a list
best_indices_list = list(best_indices_SD)

# Get the column names corresponding to the best indices
column_names = bands_df.columns[best_indices_list]

# Print the results
print("Best indices:", best_indices_SD)
print("Corresponding column names:", column_names)

# Mutate a new column, SD which is the columns at best_indices_list[0] - best_indices_list[1]
indices_df["SD"] = indices_df.iloc[:, best_indices_list[0]] - indices_df.iloc[:, best_indices_list[1]]
# Out:
# Best indices: (754, 755)
# Corresponding column names: Index(['1938', '1941'], dtype='object')

# %%
# Determine the columns for SR Index

# Create the find_optimal_indices function
def find_optimal_indices(data, target):
    num_columns = data.shape[1]
    best_correlation = 0
    best_indices = None

    for i in range(num_columns - 1):
        for j in range(i + 1, num_columns):
            divided_data = data.iloc[:, i] / data.iloc[:, j]
            correlation = np.corrcoef(divided_data, target)[0, 1]
            if abs(correlation) > best_correlation:
                best_correlation = abs(correlation)
                best_indices = (i, j)

    return best_indices

# Find the best indices
best_indices_SR = find_optimal_indices(bands_df, target)

# Convert best_indices tuple to a list
best_indices_list = list(best_indices_SR)

# Get the column names corresponding to the best indices
column_names = bands_df.columns[best_indices_list]

# Print the results
print("Best indices:", best_indices_SR)
print("Corresponding column names:", column_names)

# Mutate a new column, SR which is the columns at best_indices_list[0] / best_indices_list[1]
indices_df["SR"] = indices_df.iloc[:, best_indices_list[0]] / indices_df.iloc[:, best_indices_list[1]]
# Out:
# Best indices: (903, 910)
# Corresponding column names: Index(['2318', '2334'], dtype='object')

# %%
# Determine the columns for ND Index

# Create the find_optimal_indices function
def find_optimal_indices(data, target):
    num_columns = data.shape[1]
    best_correlation = 0
    best_indices = None

    for i in range(num_columns - 1):
        for j in range(i + 1, num_columns):
            calculated_data = np.abs(data.iloc[:, i] - data.iloc[:, j]) / (data.iloc[:, i] + data.iloc[:, j])
            correlation = np.corrcoef(calculated_data, target)[0, 1]
            if abs(correlation) > best_correlation:
                best_correlation = abs(correlation)
                best_indices = (i, j)

    return best_indices

# Find the best indices
best_indices_ND = find_optimal_indices(bands_df, target)

# Convert best_indices tuple to a list
best_indices_list = list(best_indices_ND)

# Get the column names corresponding to the best indices
column_names = bands_df.columns[best_indices_list]

# Print the results
print("Best indices:", best_indices_ND)
print("Corresponding column names:", column_names)

# Mutate a new column, ND which is the columns at |best_indices_list[0] − best_indices_list[1]|/(best_indices_list[0] + best_indices_list[1])
indices_df["ND"] = np.abs(indices_df.iloc[:, best_indices_list[0]] - indices_df.iloc[:, best_indices_list[1]]) / (indices_df.iloc[:, best_indices_list[0]] + indices_df.iloc[:, best_indices_list[1]])
# Out:
# Best indices: (10, 739)
# Corresponding column names: Index(['354', '1894'], dtype='object')

# %%
# Please select Runtime > Change Runtime Type > T4 GPU
DEVICE = 'cuda:0' if t.cuda.is_available() else 'cpu:0'

#Parse hypespectral bands (bands) and Water Potential (Mpa) (target) from dataset
df_np = drought_df.to_numpy()
target = drought_df['RWC'].to_numpy()
new_target = t.from_numpy(target.astype(np.float32)).to(device=DEVICE)
bands = t.from_numpy(df_np[:, 1:].astype(np.float32)).to(device=DEVICE)

#Customized correlation coefficient function
def corrcoef(X, y):
  """
  X is (n, m) array
  with m samples and n possible mdatt indices

  y is (1, m) array with m samples and
  """
  mu_X = X.mean(axis=-1, keepdims=True)
  mu_y = y.mean(axis=-1, keepdims=True)
  Xcent = X - mu_X # X centered around origin
  ycent = y - mu_y # y centered around origin
  n = X.shape[-1]
  C_ij = (Xcent * ycent).sum(axis=-1) / (n - 1)
  C_ii = (Xcent * Xcent).sum(axis=-1) / (n - 1)
  C_jj = (ycent * ycent).sum(axis=-1) / (n - 1)
  return C_ij / ((C_ii * C_jj).sqrt())

#Function that finds the best MDATT indices based on the absolute value of corrcoef
def _find_mdatt_indices(bands, new_target):
  best_correlation = -np.inf

  #Vectorization of bands for increased efficiency
  bands_i = bands[:, :, np.newaxis, np.newaxis]
  bands_j = bands[:, np.newaxis, :, np.newaxis]
  bands_k = bands[:, np.newaxis, np.newaxis, :]

  B = 50 # Batch size
  MAXB = 993 # Max bands
  for i in range(0, MAXB, B):
    end_i = min(i+B, MAXB)
    for j in range(0, MAXB, B):
      end_j = min(j+B, MAXB)
      for k in range(0, MAXB, B):
        end_k = min(k+B, MAXB)
        this_band_i = bands_i[:, i:end_i, :, :]
        this_band_j = bands_j[:, :, j:end_j, :]
        this_band_k = bands_k[:, :, :, k:end_k]
        bands_kj_diff = this_band_k - this_band_j
        bands_kj_diff = t.where(
            bands_kj_diff == 0,
            1e-4, bands_kj_diff)
        mdatt = (this_band_k - this_band_i) / bands_kj_diff
        mdatt_shape = mdatt.shape # (37,65,65,65)
        correlation = corrcoef(mdatt.reshape(37, -1).T, new_target).abs() # (65^3, 37) , (1, 37)
        
        correlation[correlation.isnan()] = 0 # Remove nans
        i_j_k_ravelled = (correlation).cpu().numpy().argmax() # convert to numpy
        bi, bj, bk = np.unravel_index(i_j_k_ravelled, mdatt_shape[1:]) #getting the best indices within the batch
        x = correlation[i_j_k_ravelled]
        if x > best_correlation:
          best_correlation = x
          best_indices = (bi+i, bj+j, bk+k) #saving the absolute index value of the best mdatt bands
            
  return best_indices

def find_mdatt_indices(*args, **kw):
  with t.no_grad(): # disable autogradients
    return _find_mdatt_indices(*args, **kw)

# %%
# Find the best indices
best_indices_MDATT = _find_mdatt_indices(bands, new_target)

# Convert best_indices tuple to a list
best_indices_list = list(best_indices_MDATT)

# Get the column names corresponding to the best indices
column_names = bands_df.columns[best_indices_list]

# Print the results
print("Best indices:", best_indices_MDATT)
print("Corresponding column names:", column_names)

# Mutate a new column, MDATT which is (Rλ3 − Rλ1)/(Rλ3 − Rλ2)
indices_df["MDATT"] = (indices_df.iloc[:, best_indices_list[2]] - indices_df.iloc[:, best_indices_list[0]]) / (indices_df.iloc[:, best_indices_list[2]] - indices_df.iloc[:, best_indices_list[1]])
# Out:
# Best indices: (363, 367, 408)
# Corresponding column names: Index(['837', '842', '892'], dtype='object')

# %%
# Get all rows and columns from the index 994
indices_df = indices_df.iloc[:, 994:]

# Append the target column to the indices_df
indices_df['RWC'] = target

indices_df
# Out:
#         DWSI       MSI     LWVI1     LWVI2      NDII      NDWI       WBI  \
# 0   1.190506  0.566488  0.012489  0.043199  0.246819  0.051212  0.964867
# 1   0.618247  0.613605  0.012485  0.033338  0.211824  0.041076  0.967167
# 2   0.877961  0.599918  0.013940  0.040439  0.218082  0.042208  0.971235
# 3   0.812883  0.574080  0.001007  0.038107  0.246667  0.062585  0.960879
# 4   0.817941  0.594934  0.007980  0.037414  0.228148  0.051164  0.965721
# 5   1.113783  0.553372  0.010472  0.042940  0.257311  0.057770  0.959669
# 6   0.760633  0.618255  0.012796  0.034006  0.207243  0.036840  0.973392
# 7   0.929934  0.628798  0.004159  0.033353  0.202634  0.049588  0.969680
# 8   0.889895  0.625644  0.001881  0.034600  0.204862  0.052669  0.969973
# 9   1.044195  0.603051  0.011833  0.038036  0.213748  0.036809  0.976184
# 10  0.921727  0.595677  0.005115  0.037292  0.225714  0.052005  0.970410
# 11  0.715171  0.633475  0.014210  0.034147  0.192699  0.034566  0.973453
# 12  0.870220  0.583259  0.003520  0.036866  0.238060  0.062239  0.963441
# 13  0.781790  0.577697  0.001796  0.038647  0.243224  0.065502  0.958763
# 14  0.928809  0.583377  0.006843  0.038755  0.239908  0.056636  0.963382
# 15  1.049669  0.601376  0.015040  0.038467  0.219300  0.040597  0.968992
# 16  0.953114  0.596208  0.006858  0.037406  0.225817  0.051974  0.965310
# 17  0.815580  0.623873  0.009979  0.033876  0.202578  0.042379  0.970400
# 18  0.784024  0.653630  0.014031  0.032133  0.180143  0.037517  0.965053
# 19  0.849915  0.561994  0.004801  0.039740  0.255132  0.059906  0.959334
# 20  0.912649  0.605526  0.008505  0.034590  0.221897  0.050458  0.963333
# 21  1.125231  0.556736  0.011524  0.043697  0.253245  0.058301  0.958379
# 22  1.144027  0.597329  0.012682  0.036597  0.226650  0.048201  0.964706
# 23  0.711627  0.596572  0.009150  0.038171  0.223610  0.049451  0.965423
# 24  1.190889  0.581026  0.008928  0.038300  0.237747  0.054479  0.964679
# 25  0.741769  0.646736  0.006176  0.028845  0.193903  0.037736  0.977094
# 26  0.674296  0.633061  0.007690  0.032737  0.198245  0.047449  0.974153
# 27  0.844549  0.600962  0.000461  0.035932  0.225167  0.056112  0.966979
# 28  0.899486  0.593589  0.008216  0.037345  0.229751  0.048974  0.969466
# 29  0.738312  0.741278  0.002348  0.020684  0.135952  0.026910  0.988552
# 30  0.833617  0.614105  0.006944  0.035899  0.215774  0.048288  0.972982
